# %%
import pandas as pd
import matplotlib.pyplot as plt

df = pd.read_csv("management-positions.csv")
df.rename(columns={'Pacific Island Countries and territories':'island'}, inplace=True)
print(df.columns)
df = df[["island", "TIME_PERIOD", "OBS_VALUE", "Age"]]
df.columns = ["island", "year", "share_female_lead", "age"]
df.sort_values(by=["year", "island", "age"])
# Out:
# Index(['STRUCTURE', 'STRUCTURE_ID', 'STRUCTURE_NAME', 'ACTION', 'FREQ',
#        'Frequency', 'INDICATOR', 'Indicator', 'GEO_PICT', 'island', 'SEX',
#        'Sex', 'AGE', 'Age', 'URBANIZATION', 'Urbanization', 'INCOME', 'Income',
#        'EDUCATION', 'Education level', 'OCCUPATION', 'Occupation',
#        'COMPOSITE_BREAKDOWN', 'Composite breakdown', 'DISABILITY',
#        'Disability', 'TIME_PERIOD', 'Time', 'OBS_VALUE', 'Observation value',
#        'UNIT_MEASURE', 'Unit of measure', 'REPORTING_TYPE', 'Reporting type',
#        'NATURE', 'Nature', 'DATA_SOURCE', 'Data source', 'OBS_STATUS',
#        'Observation Status', 'OBS_COMMENT', 'Comment'],
#       dtype='object')
#                               island  year  share_female_lead    age
# 9                              Nauru  2012               34.1  25-54
# 13                             Nauru  2012               54.3  55-64
# 6                    Solomon Islands  2012               22.3  25-54
# ...
