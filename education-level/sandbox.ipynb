# %%
import pandas as pd
import matplotlib.pyplot as plt

df = pd.read_csv("education-level.csv")
df.rename(columns={'Pacific Island Countries and territories':'island'}, inplace=True)
print(df.columns)
df = df[["island", "TIME_PERIOD", "OBS_VALUE", "Sex", "Age", "Education level"]]
df.columns = ["island", "year", "count", "sex", "age", "level"]
df = df[~df["level"].isin(["Level not stated", "All education levels"])]
df.sort_values(by=["island", "year", "sex", "age", "level"]).head(20)
# Out:
# Index(['STRUCTURE', 'STRUCTURE_ID', 'STRUCTURE_NAME', 'ACTION', 'FREQ',
#        'Frequency', 'GEO_PICT', 'island', 'INDICATOR', 'Indicator', 'SEX',
#        'Sex', 'AGE', 'Age', 'URBANIZATION', 'Urbanization', 'DISABILITY',
#        'Disability', 'EDUCATION', 'Education level', 'TIME_PERIOD', 'Time',
#        'OBS_VALUE', 'Observation value', 'UNIT_MEASURE', 'Unit of measure',
#        'UNIT_MULT', 'Unit multiplier', 'OBS_STATUS', 'Observation Status',
#        'DATA_SOURCE', 'Data source', 'OBS_COMMENT', 'Comment', 'CONF_STATUS',
#        'Confidentiality status'],
#       dtype='object')
#       island  year  count     sex    age  \
# 17  Kiribati  2020    384  Female  25-54
# 19  Kiribati  2020   7166  Female  25-54
# 21  Kiribati  2020    432  Female  25-54
# 18  Kiribati  2020   1450  Female  25-54
# 22  Kiribati  2020    886  Female  25-54
# 20  Kiribati  2020  11118  Female  25-54
# 25  Kiribati  2020    202  Female  55-64
# 27  Kiribati  2020   2179  Female  55-64
# ...
